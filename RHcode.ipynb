# %%
import sys
#path to directory where general python files are stored
sys.path.insert(1, 'C:\\Users\\peo0005\\Documents\\Github\\sems')

from rhdata import RHdata
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import os
import seaborn as sns

#path to data file
RH_path = "\\\\arc.auburn.edu\\lab\\ohnogroup-data\\CSM-PEO0005-RL2\\RHlogs\\20240510\\20240510_092551.txt"
#import datset
rhdata = RHdata(RH_path)

# %%
rhdata.plotT()

# %%
rhdata.plotRH()

#time bounds calculate for certain period of time
start = "2024-05-10 09:30:00"
end = "2024-05-10 09:45:45"
#bounds plot it for specified time period
rhdata.plotRH([start,end])
